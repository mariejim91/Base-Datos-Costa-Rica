# %%
import pandas as  pd

# %%
df = pd.read_csv(r'C:\Users\Maria Jose\Desktop\database.csv', index_col='ID')

# %%
df
# Out:
#                           NOMBRE_SIGLAS  \
# ID
# 1                                  INEC
# 2                                 CEPAL
# 3                         BANCO MUNDIAL
# 4                                ARESEP
# 5   CONTRALORIA GENERAL DE LA REPUBLICA
# 6                                 MIVAH
# 7                                  MOPT
# 8          MINISTERIO DE LA PRESIDENCIA
# 9                                   BID
# 10            MUNICIPALIDAD DE SAN JOSÉ
#
#                                       NOMBRE_COMPLETO JERARQUIA_GLOBAL  \
# ID
# 1         INSTITUTO NACIONAL DE ESTADISTICAS Y CENSOS         NACIONAL
# 2   COMISION ECONOMICA PARA AMERICA LATINA  Y EL C...    INTERNACIONAL
# 3                                      BANCO  MUNDIAL    INTERNACIONAL
# 4      AUTORIDAD REGULADORA DE LOS SERVICIOS PUBLICOS         NACIONAL
# 5                 CONTRALORIA GENERAL DE LA REPUBLICA         NACIONAL
# 6      MINISTERIO DE VIVIENDA Y ASENTAMIENTOS HUMANOS         NACIONAL
# ...

# %%
df.columns
# Out:
# Index(['NOMBRE_SIGLAS', 'NOMBRE_COMPLETO', 'JERARQUIA_GLOBAL',
#        'NIVEL_SECTOR_PUBLICO', 'NATURALEZA_JURIDICA', 'DEPENDENCIA',
#        'ENLACE_WEB_BASE_DE_DATOS', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df = df[['NOMBRE_SIGLAS', 'NOMBRE_COMPLETO', 'JERARQUIA_GLOBAL',
       'NIVEL_SECTOR_PUBLICO', 'NATURALEZA_JURIDICA', 'DEPENDENCIA',
       'ENLACE_WEB_BASE_DE_DATOS']]

# %%
df[['NOMBRE_SIGLAS','JERARQUIA_GLOBAL',
       'NIVEL_SECTOR_PUBLICO', 'NATURALEZA_JURIDICA', 'DEPENDENCIA',
       'ENLACE_WEB_BASE_DE_DATOS']]
# Out:
#                           NOMBRE_SIGLAS JERARQUIA_GLOBAL  \
# ID
# 1                                  INEC         NACIONAL
# 2                                 CEPAL    INTERNACIONAL
# 3                         BANCO MUNDIAL    INTERNACIONAL
# 4                                ARESEP         NACIONAL
# 5   CONTRALORIA GENERAL DE LA REPUBLICA         NACIONAL
# 6                                 MIVAH         NACIONAL
# 7                                  MOPT         NACIONAL
# 8          MINISTERIO DE LA PRESIDENCIA         NACIONAL
# 9                                   BID    INTERNACIONAL
# 10            MUNICIPALIDAD DE SAN JOSÉ         NACIONAL
#
#     NIVEL_SECTOR_PUBLICO                         NATURALEZA_JURIDICA  \
# ID
# 1                    2.0                        INSTITUCION AUTÓNOMA
# 2                    NaN                                         NaN
# 3                    NaN                                         NaN
# ...
